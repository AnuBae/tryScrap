# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import mysql.connector

# konektor ke database
db = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',
        database='UnNgGrape'
        )
cursor = db.cursor()

# scrape berdasarkan data keyword
cursor.execute("SELECT * FROM keyword")
raw_keyword = cursor.fetchall()
for row2 in raw_keyword:
    # penyiapan scraping
    keyword = row2[0]
    
    r = Request("https://www.jobstreet.co.id/id/job-search/" + keyword + "-jobs/", headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    print(r)
    response = urlopen(r).read()
    print(type(response))

    soup = BeautifulSoup(response, "lxml")
    print(type(soup))

    # inisialisasi array untuk menampilkan hasil
    title_lowongan = []
    nama_perusahaan = []
    lokasi_perusahaan = []
    link_lowongan = []

    jobList = soup.find_all("div","sx2jih0 zcydq82a _27u74_0")
    for p in jobList:
        lowongan = p.find("h1", "sx2jih0 zcydq82q _18qlyvc0 _18qlyvcv _18qlyvc3 _18qlyvc8").get_text()
        # menggunakan try except karena ada beberapa perusahaan yang dirahasiakan
        try:
            perusahaan = p.find("span", "sx2jih0 zcydq82q _18qlyvc0 _18qlyvcv _18qlyvc1 _18qlyvc8").get_text()
        except:
            perusahaan = "Perusahaan Dirahasiakan"
        lokasi = p.find("span", "sx2jih0 zcydq82q zcydq810 iwjz4h0").get_text()
        link = "https://www.jobstreet.co.id"+p.find('a').get("href")
        
        # mengecek apakah data sudah adat atau belum
        cursor.execute("SELECT * FROM jobstreet WHERE link_lowongan = '" + link + "'")
        data = cursor.fetchall()
        
        # if else untuk pengecekan input data
        if data:
            print("Data exists")
        else:
            cursor.execute(
                        "INSERT INTO jobstreet(title_lowongan, nama_perusahaan, lokasi_perusahaan, link_lowongan)"
                        "VALUES ('"+ lowongan.replace("'", "").replace('"', '') +"', '"+ perusahaan.replace("'", "").replace('"', '') +"', '"+ lokasi.replace("'", "").replace('"', '') +"', '"+ link +"')"
                        )
            
            db.commit()
            print("Data has been added")
        
        title_lowongan.append(lowongan)
        nama_perusahaan.append(perusahaan)
        lokasi_perusahaan.append(lokasi)
        link_lowongan.append(link)

jobList_dict ={'lowongan':title_lowongan, 'perusahaan':nama_perusahaan, 'lokasi':lokasi_perusahaan, 'link':link_lowongan}
df = pd.DataFrame(jobList_dict,columns = ['lowongan','perusahaan', 'lokasi', 'link'])

df.sort_values('lowongan',ascending=True)
# Out:
# <urllib.request.Request object at 0x00000226FF828640>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x00000226FF8288B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226FFAE92E0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226FFD9A4F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680060970>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680306A30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226805B2A00>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x00000226808621F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680AE9490>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226803060D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226FFAD7340>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226802DFD60>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226801D9220>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680646FA0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680FD8DC0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022681296D90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x0000022681558A90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022681276F40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680AFAE50>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x0000022680377F40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x00000226FF9A90A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002268027DAF0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680B1FEB0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680B1FFD0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x0000022680DB4DF0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
#                                    lowongan  \
# 9            Fullstack System Administrator
# 1               INFORMATION SYSTEM ENGINEER
# 12                                  IT Head
# 7                       IT Network Engineer
# 8   NETWORK INFRASTRUCTURE/DEV-OPS ENGINEER
# 3                 Network & System Engineer
# 2                          Network Engineer
# 10                         Network Engineer
# 13                         Network Engineer
# 14                 Network Engineer (IPNOM)
# 4              Network Engineer Team Leader
# 5                    Network Infrastructure
# 6                 Network Security Engineer
# 0                         SENIOR IT NETWORK
# 11                        Solution Engineer
#
#                                   perusahaan                      lokasi  \
# 9                Bentang Inspirasi Teknologi                     Bandung
# 1                    PT. Hasta Karya Perdana                    Surabaya
# 12                    PT KARYA TEKHNIK UTAMA                Jakarta Raya
# 7                    Perusahaan Dirahasiakan     Perusahaan Dirahasiakan
# 8                      VIRTUAL PROPERTI PLUS                Jakarta Raya
# 3                         PT ILOGO INFRALOGY   Jakarta Barat, Purwakarta
# 2     PT Prestasi Piranti Informasi (NEUVIZ)                Jakarta Raya
# 10                         PT Radinka Anugra                Jakarta Raya
# 13            PT. Mega Bintang Mas Indonesia                       Medan
# 14                  PT Iforte Solusi Infotek  Semarang, Bandung, Cirebon
# 4                          PT Radinka Anugra                Jakarta Raya
# 5   Yummy Corp. (Afiliation of ISMAYA GROUP)                Jakarta Raya
# 6        PT Dinamika Sistem Integrasi Solusi                Jakarta Raya
# 0                  PT Otto Menara Globalindo                  Jawa Timur
# 11                      PT Fujitsu Indonesia               Jakarta Pusat
#
#                                                  link
# 9   https://www.jobstreet.co.id/id/job/fullstack-s...
# 1   https://www.jobstreet.co.id/id/job/information...
# 12  https://www.jobstreet.co.id/id/job/it-head-363...
# 7   https://www.jobstreet.co.id/id/job/it-network-...
# 8   https://www.jobstreet.co.id/id/job/network-inf...
# 3   https://www.jobstreet.co.id/id/job/network-sys...
# 2   https://www.jobstreet.co.id/id/job/network-eng...
# 10  https://www.jobstreet.co.id/id/job/network-eng...
# 13  https://www.jobstreet.co.id/id/job/network-eng...
# 14  https://www.jobstreet.co.id/id/job/network-eng...
# 4   https://www.jobstreet.co.id/id/job/network-eng...
# 5   https://www.jobstreet.co.id/id/job/network-inf...
# 6   https://www.jobstreet.co.id/id/job/network-sec...
# 0   https://www.jobstreet.co.id/id/job/senior-it-n...
# 11  https://www.jobstreet.co.id/id/job/solution-en...
