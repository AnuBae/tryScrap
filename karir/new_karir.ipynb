# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import mysql.connector

# konektor ke database
db = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',
        database='UnNgGrape'
        )
cursor = db.cursor()

# scrape berdasarkan data keyword
cursor.execute("SELECT * FROM keyword")
raw_keyword = cursor.fetchall()
for row2 in raw_keyword:
    # penyiapan scraping
    keyword = row2[0]

    r = Request("https://www.karir.com/search?q=" + keyword +"&sort_order=urgent_job&job_function_ids=&industry_ids=&degre", headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    print(r)
    response = urlopen(r).read()
    print(type(response))

    soup = BeautifulSoup(response, "lxml")
    print(type(soup))

    # inisialisasi array untuk menampilkan hasil
    title_lowongan = []
    nama_perusahaan = []
    lokasi_perusahaan = []
    link_lowongan = []

    jobList = soup.find_all("div", "row opportunity-box")
    for p in jobList:
        lowongan = p.find("h4", "tdd-function-name").get_text()
        # menggunakan try except karena ada beberapa perusahaan yang dirahasiakan
        try:
            perusahaan = p.find("div", "tdd-company-name").get_text()
        except:
            perusahaan = "Perusahaan Dirahasiakan"
        lokasi = p.find("span", "tdd-location").get_text().replace("head office - ", "")
        link = "https://karir.com"+p.find('a').get("href")
        
        # mengecek apakah data sudah adat atau belum
        cursor.execute("SELECT * FROM karir WHERE link_lowongan = '" + link + "'")
        data = cursor.fetchall()
        # if else untuk pengecekan input data
        if data:
            print("Data exists")
        else:
            cursor.execute(
                        "INSERT INTO karir(title_lowongan, nama_perusahaan, lokasi_perusahaan, link_lowongan)"
                        "VALUES ('"+ lowongan.replace("'", "").replace('"', '') +"', '"+ perusahaan.replace("'", "").replace('"', '') +"', '"+ lokasi.replace("'", "").replace('"', '') +"', '"+ link +"')"
                        )
            
            db.commit()
            print("Data has been added")
        
        title_lowongan.append(lowongan)
        nama_perusahaan.append(perusahaan)
        lokasi_perusahaan.append(lokasi)
        link_lowongan.append(link)

jobList_dict ={'lowongan':title_lowongan, 'perusahaan':nama_perusahaan, 'lokasi':lokasi_perusahaan, 'link':link_lowongan}
df = pd.DataFrame(jobList_dict,columns = ['lowongan','perusahaan', 'lokasi', 'link'])

df.sort_values('lowongan',ascending=True)
# Out:
# <urllib.request.Request object at 0x000001857C708460>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857C9D7910>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857C9D7A30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CA354F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# <urllib.request.Request object at 0x000001857CB06C10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857C9FB460>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CBC5F40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CBD2040>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CBD20A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CBB8F10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CD3A1F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CE0C400>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CE91790>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CEFD190>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CE73FD0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CFAB910>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857D08BFD0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D0E7160>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D1B26D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D238C40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D2B8580>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# <urllib.request.Request object at 0x000001857D385730>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857D3D3940>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857D41CA90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D467D60>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D4AE580>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D3D3370>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D50D130>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857E53D730>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857E5AD5B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E5C2190>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857E5033A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857E5ADAC0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E5ADB20>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857C937160>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E5520D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857C9D7A30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857C9D7E80>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857C92CD90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CF94F70>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D4A8490>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857C95CC10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857D35F8B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857CAFAFA0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CD280D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857D0B0A00>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857E578C40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001857CF01970>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# <urllib.request.Request object at 0x000001857CE71B50>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CBB7D90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857D34D520>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CE61550>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CD7F760>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CD7F700>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CAA7A30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CDA9400>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CE06EE0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CF6C070>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CF60EB0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857E6DE340>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857E787370>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E7AC9A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D16AE20>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857E805610>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CF94EB0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E503820>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E8D80A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CF927F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# <urllib.request.Request object at 0x000001857E525160>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857CB6A340>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CF85130>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CEEBA30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D357310>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D37AA30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857C989190>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CEEBF40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D35A1F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CA4C9A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E4EC220>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857CA282B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CA28280>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E5B4A90>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CE68C40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D333F40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D4F8760>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CC89040>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857CE37880>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D421A30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857D1D4DF0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CF19DC0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D473F10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857D295730>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D210A00>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data exists
# <urllib.request.Request object at 0x000001857CFE3D60>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857D1B7370>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CD449D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857D073F70>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E62D340>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857E62D2E0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D4A8310>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001857C97C910>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857CB5F040>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D004970>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D4FB490>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000001857D44D6A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857D1F8460>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001857D1F8430>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857E4FEDC0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000001857CA69640>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
#                                              lowongan  \
# 4                                       IT PROGRAMMER
# 2                   Application Programming Interface
# 1                   Bootcamp Fullstack PHP Programmer
# 10   DOSEN TETAP  Program Studi Manajemen Informatika
# 6   DOSEN TETAP  Program Studi Rekayasa Perangkat ...
# 0           IT Program Development & Support Engineer
# 8                                          PROGRAMMER
# 11                                        PROGRAMMER
# 9                              PROGRAMMER SPECIALIST
# 3                PRU VENTURE DEVELOPMENT PROGRAM - el
# 7                                 PRU VENTURE PROGRAM
# 12                                         Programmer
# 13                                     Programmer Web
# 14             Retail Funding Training Program (RFTP)
# 5                  Technical Programmer Unreal Engine
#
#                               perusahaan  \
# 4                         Urban Athletes
# 2           PT Tripedia Global Adventura
# 1                  PT Asta Protek Jiarsi
# 10               Universitas Bina Insani
# 6                Universitas Bina Insani
# 0                   PT Mitra Adi Persada
# 8   PT Prime Consulting Executive Search
# 11       PT Intrias Mandiri Sejati (IMS)
# 9              PT KMI Wire And Cable Tbk
# 3                       Baroroh Elbariah
# 7                       Baroroh Elbariah
# 12                           ASABA GROUP
# 13                      PT Edi Indonesia
# 14                     PT Bank Mega, Tbk
# 5                   Visual Addict Studio
#
#                                                lokasi  \
# 4                                 SURABAYA - Surabaya
# 2                                            Semarang
# 1                   PT Asta Protek Jiarsi - Tangerang
# 10                                             Bekasi
# 6                                              Bekasi
# 0                     Head Office Surabaya - Surabaya
# 8                                           Tangerang
# 11                                  Prov. DKI-Jakarta
# 9                                       Jakarta Timur
# 3                             FP One  - Jakarta Pusat
# 7                             FP One  - Jakarta Pusat
# 12                                      Jakarta Pusat
# 13                                      Jakarta Utara
# 14              Prov. Jawa Tengah - Prov. Jawa Tengah
# 5   Visual Addict Studio (Film Industry) - Jakarta...
#
#                                                  link
# 4             https://karir.com/opportunities/1322281
# 2             https://karir.com/opportunities/1322319
# 1             https://karir.com/opportunities/1323668
# 10            https://karir.com/opportunities/1321780
# 6             https://karir.com/opportunities/1321781
# 0             https://karir.com/opportunities/1322892
# 8             https://karir.com/opportunities/1322787
# 11            https://karir.com/opportunities/1323145
# 9   https://karir.com/opportunities/1315167?offlin...
# 3             https://karir.com/opportunities/1322005
# 7             https://karir.com/opportunities/1321707
# 12            https://karir.com/opportunities/1321574
# 13            https://karir.com/opportunities/1321923
# 14            https://karir.com/opportunities/1319755
# 5             https://karir.com/opportunities/1319850
