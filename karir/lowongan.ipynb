# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import mysql.connector

# konektor ke database
db = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',
        database='UnNgGrape'
        )
cursor = db.cursor()

cursor.execute("SELECT * FROM keyword")
raw_keyword = cursor.fetchall()
for row in raw_keyword:
    # penyiapan scraping
    keyword = row[0]
    r = Request("https://www.karir.com/search?q=" + keyword + "&sort_order=urgent_job&job_function_ids=&industry_ids=&degree_ids=&major_ids=&location_ids=&location_id=&location=&salary_lower=0&salary_upper=100000000&page=0&grid=list", headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    print(r)
    response = urlopen(r).read()
    print(type(response))

    soup = BeautifulSoup(response, "lxml")
    print(type(soup))

    jobList = soup.find_all("div","row opportunity-box")
    for p in jobList:
        lowongan = p.find('h4', "tdd-function-name").get_text()
        # menggunakan try except karena ada beberapa perusahaan yang dirahasiakan
        try:
            perusahaan = p.find('div', "tdd-company-name").get_text()
        except:
            perusahaan = "Perusahaan Dirahasiakan"
        lokasi = p.find('span', "tdd-location").get_text()
        link = "https://m.karir.com"+p.find('a').get('href')

        cursor.execute("SELECT * FROM karir WHERE link_lowongan = '" + link + "'")
        data = cursor.fetchall()
        # if else untuk pengecekan input data
        if data:
            print("Data exists")
        else:
            #   scrape detail sesuai link
            r2 = Request(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
            response2 = urlopen(r2).read()
            
            soup2 = BeautifulSoup(response2, "lxml")
            raw_deskripsi = soup2.find('div', "tdd-opportunities-section__new")
            # increment deskripsi
            deskripsi = ""
            for string in raw_deskripsi.strings:
                new_string  = deskripsi + " " + string
                deskripsi = new_string

            # menghilangkan Apostrophe mark
            # deskripsi.replace("'","")

            cursor.execute(
                "INSERT INTO karir(title_lowongan, nama_perusahaan, lokasi_perusahaan, deskripsi_lowongan, link_lowongan)"
                "VALUES ('"+ lowongan.replace("'", "").replace('"', '') +"', '"+ perusahaan.replace("'", "").replace('"', '') +"', '"+ lokasi.replace("'", "").replace('"', '') +"', '"+ deskripsi.replace("'", "").replace('"', '') +"', '"+ link +"')"
                )
            print("Data has been added")
    
db.commit()
print("________________________________________DONE________________________________________")
# Out:
# <urllib.request.Request object at 0x000002E52EFBB220>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E531691DC0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E531A64700>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data has been added
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E5318999D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000002E53186CB80>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E5324381F0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E5320944C0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E53243FCA0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E53173AA00>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E531CE66A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E531F2A0A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000002E532087CA0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E533625EB0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E5337EAAF0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E533847D30>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000002E533625D60>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000002E53170E130>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000002E533891430>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000002E53219AC10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000002E531F99DF0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000002E531722D60>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data has been added
# Data has been added
# Data has been added
# Data has been added
# <urllib.request.Request object at 0x000002E531746F10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000002E531D008B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000002E5323F4130>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# <urllib.request.Request object at 0x000002E53193B040>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________________________________________DONE________________________________________
