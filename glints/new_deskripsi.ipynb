# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import mysql.connector

# inisialisasi array untuk menampilkan hasil
id_detail = []
keterangan_lowongan = []
deskripsi_lowongan = []
skill_lowongan = []
benefit_lowongan = []

# konektor ke database
db = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',
        database='UnNgGrape'
        )
cursor = db.cursor()

cursor.execute("SELECT id_glints, link_lowongan FROM glints")
raw_glints = cursor.fetchall()
for row in raw_glints:
    id_glints = row[0]
    link = row[1]
    r = Request(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    response = urlopen(r).read()
    soup = BeautifulSoup(response, "lxml")

    raw_detail = soup.find_all("div","Opportunitysc__Container-sc-1gsvee3-2 gPhXzZ")
    for p in raw_detail:
        # menggunakan try except karena ada beberapa estimasi keterangan yang tidak terlampir
        try:
            raw_keterangan = soup.find_all("div", "TopFoldsc__JobOverViewInfo-kklg8i-9 eWKiJR")
            keterangan = ""
            for q in raw_keterangan:
                keterangan = q.get_text() + ". " + keterangan
        except:
            keterangan = "-"
        
        # menggunakan try except karena ada beberapa deskripsi yang NoneType
        try:
            deskripsi = p.find("div", "Opportunitysc__JobDescriptionContainer-sc-1gsvee3-6 gBmrdW" ).get_text(separator=" ").replace("Informasi Penting Pastikan perusahaan yang kamu lamar resmi dengan memeriksa website dan lowongan kerja mereka. Read Less ", "")
        except:
            deskripsi = "Eror: deskripsi Nonetype"

        try:
            skill = p.find("div", "Opportunitysc__SkillsContainer-sc-1gsvee3-7 hzDxPi").get_text(separator=" ")
        except:
            skill = '-'
        try:
            benefit = p.find("div", "Opportunitysc__BenefitsContainer-sc-1gsvee3-8 jvOXrL").get_text(separator=" ")
        except:
            benefit = '-'

        id_detail.append(id_glints)
        keterangan_lowongan.append(keterangan)
        deskripsi_lowongan.append(deskripsi)
        skill_lowongan.append(skill)
        benefit_lowongan.append(benefit)

detail_dict ={'id':id_detail, 'keterangan':keterangan_lowongan, 'deskripsi':deskripsi_lowongan, 'skill':skill_lowongan, 'benefit':benefit_lowongan}
df = pd.DataFrame(detail_dict, columns = ['id', 'keterangan', 'deskripsi', 'skill', 'benefit'])

df.sort_values('id', ascending=True)
# Out:
#       id                                         keterangan  \
# 0    968   1 - 3 tahun pengalaman. Full-Time. Engineering.
# 1    969  3 - 5 tahun pengalaman. Full-Time. Engineering...
# 2    970    3 - 5 tahun pengalaman. Full-Time. Operations.
# 3    971                            Full-Time. Operations.
# 4    972   1 - 3 tahun pengalaman. Full-Time. Engineering.
# 5    973  5 - 10 tahun pengalaman. Full-Time. Finance. I...
# 6    974  Full-Time. Engineering. IDR5,000,000 - 10,000,...
# 7    975  Pengalaman kurang dari 1 tahun. Magang. Engine...
# 8    976  1 - 3 tahun pengalaman. Full-Time. Data Scienc...
# 9    977  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 10   978  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 11   979  1 - 3 tahun pengalaman. Full-Time. Business De...
# 12   980  1 - 3 tahun pengalaman. Full-Time. Business De...
# 13   981  1 - 3 tahun pengalaman. Full-Time. Administrat...
# 14   982  3 - 5 tahun pengalaman. Full-Time. Engineering...
# 15   983  1 - 3 tahun pengalaman. Full-Time. Marketing. ...
# 16   984  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 17   985  1 - 3 tahun pengalaman. Full-Time. Software En...
# 18   986  Pengalaman kurang dari 1 tahun. Full-Time. Eng...
# 19   987  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 20   988  Pengalaman kurang dari 1 tahun. Full-Time. Sof...
# 21   989  1 - 3 tahun pengalaman. Full-Time. Product Man...
# 22   990  1 - 3 tahun pengalaman. Full-Time. Software En...
# 23   991  Pengalaman kurang dari 1 tahun. Full-Time. Dat...
# 24   992  Pengalaman kurang dari 1 tahun. Full-Time. Sof...
# 25   993  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 26   994  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 27   995  5 - 10 tahun pengalaman. Full-Time. Business D...
# 28   996  Pengalaman kurang dari 1 tahun. Full-Time. Eng...
# 29   997   1 - 3 tahun pengalaman. Full-Time. Engineering.
# 30   998  3 - 5 tahun pengalaman. Full-Time. Engineering...
# 31   999    3 - 5 tahun pengalaman. Full-Time. Operations.
# 32  1000                            Full-Time. Operations.
# 33  1001   1 - 3 tahun pengalaman. Full-Time. Engineering.
# 34  1002  5 - 10 tahun pengalaman. Full-Time. Finance. I...
# 35  1003  Full-Time. Engineering. IDR5,000,000 - 10,000,...
# 36  1004  Pengalaman kurang dari 1 tahun. Magang. Engine...
# 37  1005  1 - 3 tahun pengalaman. Full-Time. Data Scienc...
# 38  1006  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 39  1007  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 40  1008  1 - 3 tahun pengalaman. Full-Time. Business De...
# 41  1009  1 - 3 tahun pengalaman. Full-Time. Business De...
# 42  1010  1 - 3 tahun pengalaman. Full-Time. Administrat...
# 43  1011  3 - 5 tahun pengalaman. Full-Time. Engineering...
# 44  1012  1 - 3 tahun pengalaman. Full-Time. Marketing. ...
# 45  1013  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 46  1014  1 - 3 tahun pengalaman. Full-Time. Software En...
# 47  1015  Pengalaman kurang dari 1 tahun. Full-Time. Eng...
# 48  1016  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 49  1017  Pengalaman kurang dari 1 tahun. Full-Time. Sof...
# 50  1018  1 - 3 tahun pengalaman. Full-Time. Product Man...
# 51  1019  1 - 3 tahun pengalaman. Full-Time. Software En...
# 52  1020  Pengalaman kurang dari 1 tahun. Full-Time. Dat...
# 53  1021  Pengalaman kurang dari 1 tahun. Full-Time. Sof...
# 54  1022  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 55  1023  1 - 3 tahun pengalaman. Full-Time. Engineering...
# 56  1024  5 - 10 tahun pengalaman. Full-Time. Business D...
# 57  1025  Pengalaman kurang dari 1 tahun. Full-Time. Eng...
# 58  1026  1 - 3 tahun pengalaman. Full-Time. Engineering...
#
#                                             deskripsi  \
# 0   Deskripsi pekerjaan TEKNIK  ENGINEERING PT Mar...
# 1   Deskripsi pekerjaan Asisten Direktur Teknik Pt...
# 2   Deskripsi pekerjaan Kepala Seksi Teknik Pt Tri...
# 3   Deskripsi pekerjaan Staff Teknik Lapangan PT H...
# 4   Deskripsi pekerjaan Ahli Teknik Elektromedik (...
# 5   Deskripsi pekerjaan Finance & Accounting Assis...
# 6   Deskripsi pekerjaan Electronics Engineers & Te...
# 7   Deskripsi pekerjaan MAGANG - TEKNISI LISTRIK G...
# 8   Deskripsi pekerjaan SENIOR DATA SCIENTIST Pt. ...
# 9   Deskripsi pekerjaan FULL-STACK ENGINEER Pt. Sh...
# 10  Deskripsi pekerjaan DATA ENGINEER Pt. Sharing ...
# 11  Deskripsi pekerjaan Project Sales Pt. Java Sur...
# 12  Deskripsi pekerjaan Sales Engineer Pt Iniled I...
# 13  Deskripsi pekerjaan Admin Reporting  Tribhakti...
# 14  Deskripsi pekerjaan SPV ENGINEERING Pt Aice Ic...
# 15  Deskripsi pekerjaan DIRECT MARKETING STAFF PT....
# 16  Deskripsi pekerjaan MEP Engineer dan Drafter P...
# 17  Deskripsi pekerjaan HARDWARE & SOFTWARE ENGINE...
# 18  Deskripsi pekerjaan Teknisi Larissa Aesthetic ...
# 19  Deskripsi pekerjaan CNC Operator PT Gloster Fu...
# 20  Deskripsi pekerjaan Software Development Pt So...
# 21  Deskripsi pekerjaan SPV DRAFTER PT Fajar Lesta...
# 22  Deskripsi pekerjaan IT Programmer PT Cahaya Sa...
# 23  Deskripsi pekerjaan SEO Analyst Mnc Portal Ind...
# 24  Deskripsi pekerjaan Online Bootcamp Fullstack ...
# 25  Deskripsi pekerjaan IT Network  PT Cahaya Sakt...
# 26  Deskripsi pekerjaan TEKNISI - CIKARANG Pt Orie...
# 27  Deskripsi pekerjaan Sales & Marketing Manager ...
# 28  Deskripsi pekerjaan Engineering Staff PT Citra...
# 29  Deskripsi pekerjaan TEKNIK  ENGINEERING PT Mar...
# 30  Deskripsi pekerjaan Asisten Direktur Teknik Pt...
# 31  Deskripsi pekerjaan Kepala Seksi Teknik Pt Tri...
# 32  Deskripsi pekerjaan Staff Teknik Lapangan PT H...
# 33  Deskripsi pekerjaan Ahli Teknik Elektromedik (...
# 34  Deskripsi pekerjaan Finance & Accounting Assis...
# 35  Deskripsi pekerjaan Electronics Engineers & Te...
# 36  Deskripsi pekerjaan MAGANG - TEKNISI LISTRIK G...
# 37  Deskripsi pekerjaan SENIOR DATA SCIENTIST Pt. ...
# 38  Deskripsi pekerjaan FULL-STACK ENGINEER Pt. Sh...
# 39  Deskripsi pekerjaan DATA ENGINEER Pt. Sharing ...
# 40  Deskripsi pekerjaan Project Sales Pt. Java Sur...
# 41  Deskripsi pekerjaan Sales Engineer Pt Iniled I...
# 42  Deskripsi pekerjaan Admin Reporting  Tribhakti...
# 43  Deskripsi pekerjaan SPV ENGINEERING Pt Aice Ic...
# 44  Deskripsi pekerjaan DIRECT MARKETING STAFF PT....
# 45  Deskripsi pekerjaan MEP Engineer dan Drafter P...
# 46  Deskripsi pekerjaan HARDWARE & SOFTWARE ENGINE...
# 47  Deskripsi pekerjaan Teknisi Larissa Aesthetic ...
# 48  Deskripsi pekerjaan CNC Operator PT Gloster Fu...
# 49  Deskripsi pekerjaan Software Development Pt So...
# 50  Deskripsi pekerjaan SPV DRAFTER PT Fajar Lesta...
# 51  Deskripsi pekerjaan IT Programmer PT Cahaya Sa...
# 52  Deskripsi pekerjaan SEO Analyst Mnc Portal Ind...
# 53  Deskripsi pekerjaan Online Bootcamp Fullstack ...
# 54  Deskripsi pekerjaan IT Network  PT Cahaya Sakt...
# 55  Deskripsi pekerjaan TEKNISI - CIKARANG Pt Orie...
# 56  Deskripsi pekerjaan Sales & Marketing Manager ...
# 57  Deskripsi pekerjaan Engineering Staff PT Citra...
# 58  Deskripsi pekerjaan SITE COORDINATOR PT. Aplik...
#
#                                                 skill  \
# 0     Skills wajib Teknik Elektro Cc+ Plc Programming
# 1   Skills wajib Architecture SketchUp Team Leader...
# 2   Skills wajib Problem Solving Teamwork Good Com...
# 3   Skills wajib Teknik Elektro Teknisi Listrik Te...
# 4   Skills wajib Mampu Bekerja Keras Dan Jujur Ser...
# 5   Skills wajib Accurate Software Laporan Keuanga...
# 6   Skills wajib Microcontrollers Electronics Hard...
# 7   Skills wajib Electrical Maintenance Electrical...
# 8   Skills wajib Sql Pyspark Regression Tableau Sp...
# 9   Skills wajib Mysql Postgress Software Develope...
# 10  Skills wajib Sql Google Data Studio Data Engin...
# 11  Skills wajib Negotiation Sales Presentation Sk...
# 12  Skills wajib Problem Solving And Time Manageme...
# 13  Skills wajib Oil and Gas Exploration Oil and G...
# 14  Skills wajib Electrical Maintenance Waste wate...
# 15  Skills wajib Marketing Communications Persuasi...
# 16  Skills wajib AutoCAD Teliti dalam bekerja Micr...
# 17  Skills wajib JavaScript Programming Basic C++ ...
# 18  Skills wajib Electrical Maintenance Technician...
# 19  Skills wajib Mechanical Engineering CNC Operat...
# 20  Skills wajib System Analyst Programming Javasc...
# 21  Skills wajib 2D & 3D Drafter Contract Drafter ...
# 22  Skills wajib Coding And Programing JavaScript ...
# 23  Skills wajib Seo/sem Google Ads Google Adwords...
# 24  Skills wajib JavaScript Php Programming SQL Sk...
# 25  Skills wajib Security System (CCTV) instalasi ...
# 26                                                  -
# 27  Skills wajib Digital Marketing Negotiable Skil...
# 28                       Skills wajib PLC AutoCAD CAD
# 29    Skills wajib Teknik Elektro Cc+ Plc Programming
# 30  Skills wajib Architecture SketchUp Team Leader...
# 31  Skills wajib Problem Solving Teamwork Good Com...
# 32  Skills wajib Teknik Elektro Teknisi Listrik Te...
# 33  Skills wajib Mampu Bekerja Keras Dan Jujur Ser...
# 34  Skills wajib Accurate Software Laporan Keuanga...
# 35  Skills wajib Microcontrollers Electronics Hard...
# 36  Skills wajib Electrical Maintenance Electrical...
# 37  Skills wajib Sql Pyspark Regression Tableau Sp...
# 38  Skills wajib Mysql Postgress Software Develope...
# 39  Skills wajib Sql Google Data Studio Data Engin...
# 40  Skills wajib Negotiation Sales Presentation Sk...
# 41  Skills wajib Problem Solving And Time Manageme...
# 42  Skills wajib Oil and Gas Exploration Oil and G...
# 43  Skills wajib Electrical Maintenance Waste wate...
# 44  Skills wajib Marketing Communications Persuasi...
# 45  Skills wajib AutoCAD Teliti dalam bekerja Micr...
# 46  Skills wajib JavaScript Programming Basic C++ ...
# 47  Skills wajib Electrical Maintenance Technician...
# 48  Skills wajib Mechanical Engineering CNC Operat...
# 49  Skills wajib System Analyst Programming Javasc...
# 50  Skills wajib 2D & 3D Drafter Contract Drafter ...
# 51  Skills wajib Coding And Programing JavaScript ...
# 52  Skills wajib Seo/sem Google Ads Google Adwords...
# 53  Skills wajib JavaScript Php Programming SQL Sk...
# 54  Skills wajib Security System (CCTV) instalasi ...
# 55                                                  -
# 56  Skills wajib Digital Marketing Negotiable Skil...
# 57                       Skills wajib PLC AutoCAD CAD
# 58  Skills wajib Kemampuan Teknik Leadership Proje...
#
#                                               benefit
# 0                                                   -
# 1   Tunjangan dan keuntungan Makanan dan minuman g...
# 2   Tunjangan dan keuntungan Tunjangan kesehatan d...
# 3                                                   -
# 4                                                   -
# 5   Tunjangan dan keuntungan Tunjangan kesehatan d...
# 6   Tunjangan dan keuntungan Waktu kerja fleksibel...
# 7                                                   -
# 8                                                   -
# 9                                                   -
# 10                                                  -
# 11  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 12  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 13                                                  -
# 14                                                  -
# 15  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 16                                                  -
# 17                   Tunjangan dan keuntungan Lainnya
# 18  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 19  Tunjangan dan keuntungan Makanan dan minuman g...
# 20  Tunjangan dan keuntungan Waktu kerja fleksibel...
# 21                                                  -
# 22                                                  -
# 23                                                  -
# 24  Tunjangan dan keuntungan Bisa kerja remote Tun...
# 25                   Tunjangan dan keuntungan Lainnya
# 26                                                  -
# 27  Tunjangan dan keuntungan Waktu kerja fleksibel...
# 28  Tunjangan dan keuntungan Makanan dan minuman g...
# 29                                                  -
# 30  Tunjangan dan keuntungan Makanan dan minuman g...
# 31  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 32                                                  -
# 33                                                  -
# 34  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 35  Tunjangan dan keuntungan Waktu kerja fleksibel...
# 36                                                  -
# 37                                                  -
# 38                                                  -
# 39                                                  -
# 40  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 41  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 42                                                  -
# 43                                                  -
# 44  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 45                                                  -
# 46                   Tunjangan dan keuntungan Lainnya
# 47  Tunjangan dan keuntungan Tunjangan kesehatan d...
# 48  Tunjangan dan keuntungan Makanan dan minuman g...
# 49  Tunjangan dan keuntungan Waktu kerja fleksibel...
# 50                                                  -
# 51                                                  -
# 52                                                  -
# 53  Tunjangan dan keuntungan Bisa kerja remote Tun...
# 54                   Tunjangan dan keuntungan Lainnya
# 55                                                  -
# 56  Tunjangan dan keuntungan Waktu kerja fleksibel...
# 57  Tunjangan dan keuntungan Makanan dan minuman g...
# 58                                                  -
