# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import mysql.connector

# konektor ke database
db = mysql.connector.connect(
        host='localhost',
        user='root',
        password='',
        database='UnNgGrape'
        )
cursor = db.cursor()

# scrape berdasarkan data keyword
cursor.execute("SELECT * FROM keyword")
raw_keyword = cursor.fetchall()
for row2 in raw_keyword:
    # penyiapan scraping
    keyword = row2[0]

    r = Request("https://glints.com/id/opportunities/jobs/explore?keyword=" + keyword +"&country=ID&locationName=Indonesia", headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    print(r)
    response = urlopen(r).read()
    print(type(response))

    soup = BeautifulSoup(response, "lxml")
    print(type(soup))

    # inisialisasi array untuk menampilkan hasil
    title_lowongan = []
    nama_perusahaan = []
    lokasi_perusahaan = []
    link_lowongan = []

    jobList = soup.find_all("div","compact_job_card")
    for p in jobList:
        lowongan = p.find("h3", "CompactOpportunityCardsc__JobTitle-sc-1xtox99-7").get_text()
        # menggunakan try except karena ada beberapa perusahaan yang dirahasiakan
        try:
            perusahaan = p.find('a', "CompactOpportunityCardsc__CompanyLink-sc-1xtox99-8 bFxfxR").get_text()
        except:
            perusahaan = "Perusahaan Dirahasiakan"
        lokasi = p.find("div", "CompactOpportunityCardsc__OpportunityInfo-sc-1xtox99-13 hiAtMr").get_text()
        link = "https://glints.com"+p.find('a').get('href')
        
        # mengecek apakah data sudah adat atau belum
        cursor.execute("SELECT * FROM glints WHERE link_lowongan = '" + link + "'")
        data = cursor.fetchall()
        # if else untuk pengecekan input data
        if data:
            print("Data exists")
        else:
            cursor.execute(
                        "INSERT INTO glints(title_lowongan, nama_perusahaan, lokasi_perusahaan, link_lowongan)"
                        "VALUES ('"+ lowongan.replace("'", "").replace('"', '') +"', '"+ perusahaan.replace("'", "").replace('"', '') +"', '"+ lokasi.replace("'", "").replace('"', '') +"', '"+ link +"')"
                        )
            
            db.commit()
            print("Data has been added")
        
        title_lowongan.append(lowongan)
        nama_perusahaan.append(perusahaan)
        lokasi_perusahaan.append(lokasi)
        link_lowongan.append(link)

jobList_dict ={'lowongan':title_lowongan, 'perusahaan':nama_perusahaan, 'lokasi':lokasi_perusahaan, 'link':link_lowongan}
df = pd.DataFrame(jobList_dict,columns = ['lowongan','perusahaan', 'lokasi', 'link'])

df.sort_values('lowongan',ascending=True)
# Out:
# <urllib.request.Request object at 0x000001DC430A66D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC430A6850>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC435669D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# <urllib.request.Request object at 0x000001DC433A5F40>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43913880>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43ADC220>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC438E7880>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43E7A610>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC4406F070>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC4405DFA0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC45418670>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC455F5280>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC457BBF70>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC430BB2B0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC452276A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC433793A0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC45478BE0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# <urllib.request.Request object at 0x000001DC43A81940>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC431A9850>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC436C3C10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43BEEEB0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43BEEFD0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC43F27F10>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC4538D9D0>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# <urllib.request.Request object at 0x000001DC45B57F70>
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data has been added
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
# Data exists
#                                              lowongan  \
# 6                                   Account Executive
# 12                Account Executive Digital Marketing
# 5                        Business Development Manager
# 15                           DevOps & Server Engineer
# 8                                     DevOps Engineer
# 26                    Game Developer (Unity) (REMOTE)
# 4                                           IT DevOps
# 3             IT Infrastructure System Administrator
# 0                    IT Networking and Infrastructure
# 2                                          IT Support
# 20                            Java Backend Programmer
# 18                            Junior Network Engineer
# 22                                        Lead DevOps
# 16                       Management Trainee Marketing
# 27      Marketing & Sales Executive (Remote Position)
# 25                                  Mobile Programmer
# 7                                    NETWORK ENGINEER
# 24                                  Network Engineer
# 10              Onsite Engineer (CCNP) -Project Based
# 11                               PreSales Engineer IT
# 9                                         PreSales IT
# 13                                         Sales Area
# 29                   Sales Corporate Specialist (B2B)
# 21                                     Sales Director
# 28                  Sales Manager ( Penempatan Medan)
# 23                    Sales Marketing Interior Design
# 17                                    Senior IT Sales
# 14  Site Reliability Engineer (Devops) - Finance I...
# 19  Telesales Representative (KHUSUS FRESHGRADUATE...
# 1                                        iOS Engineer
#
#                            perusahaan                     lokasi  \
# 6                       Weddingmarket            Blok M, Jakarta
# 12                        Inmarketing                   Surabaya
# 5                          Softscheck                    Jakarta
# 15            Widya Imersif Teknologi                 Yogyakarta
# 8          Pt Cipta Piranti Sejahtera                  Tangerang
# 26           The Leadership Institute                    Jakarta
# 4                   Pt. Kapital Boost  Mampang Prapatan, Jakarta
# 3                             CPSSoft                  Tangerang
# 0       PT Metalogix Infolink Persada                    Jakarta
# 2         Pt. Cultureroyale Indonesia          Pancoran, Jakarta
# 20         Pt Global Logistik Ekspres                   Denpasar
# 18  Nevigate Telekomunikasi Indonesia                    Jakarta
# 22       Moslem Community Application                    Jakarta
# 16           Pt. Exacom Abadi Sentosa                    Jakarta
# 27                    Forex Autopilot                    Jakarta
# 25            Pt Baron Biondi William       Penjaringan, Jakarta
# 7                PT. Ebdesk Teknologi                  Tangerang
# 24               Dhana Jasa Konsultan                      Abang
# 10    PT Nusantara Compnet Integrator                    Jakarta
# 11              Pt. Techno9 Indonesia         Kalideres, Jakarta
# 9       Pt Interdata Teknologi Sukses         Kalideres, Jakarta
# 13       Moslem Community Application                      Medan
# 29           PT Sumber Sinergi Makmur         Kemayoran, Jakarta
# 21    PT Nusantara Compnet Integrator                    Jakarta
# 28            Pt. Artha Motor Lestari                      Medan
# 23                        Hyde Living          Palmerah, Jakarta
# 17     Pt Harnis Kreasi Internasional                  Tangerang
# 14         PT. Asian Sigma Technology                  Tangerang
# 19                    Vcloud Property                    Jakarta
# 1                    ProSpace Pte Ltd                      Batam
#
#                                                  link
# 6   https://glints.com/id/opportunities/jobs/accou...
# 12  https://glints.com/id/opportunities/jobs/accou...
# 5   https://glints.com/id/opportunities/jobs/busin...
# 15  https://glints.com/id/opportunities/jobs/devop...
# 8   https://glints.com/id/opportunities/jobs/devop...
# 26  https://glints.com/id/opportunities/jobs/game-...
# 4   https://glints.com/id/opportunities/jobs/it-de...
# 3   https://glints.com/id/opportunities/jobs/it-in...
# 0   https://glints.com/id/opportunities/jobs/it-ne...
# 2   https://glints.com/id/opportunities/jobs/it-su...
# 20  https://glints.com/id/opportunities/jobs/java-...
# 18  https://glints.com/id/opportunities/jobs/junio...
# 22  https://glints.com/id/opportunities/jobs/lead-...
# 16  https://glints.com/id/opportunities/jobs/manag...
# 27  https://glints.com/id/opportunities/jobs/marke...
# 25  https://glints.com/id/opportunities/jobs/mobil...
# 7   https://glints.com/id/opportunities/jobs/netwo...
# 24  https://glints.com/id/opportunities/jobs/netwo...
# 10  https://glints.com/id/opportunities/jobs/onsit...
# 11  https://glints.com/id/opportunities/jobs/presa...
# 9   https://glints.com/id/opportunities/jobs/presa...
# 13  https://glints.com/id/opportunities/jobs/sales...
# 29  https://glints.com/id/opportunities/jobs/sales...
# 21  https://glints.com/id/opportunities/jobs/sales...
# 28  https://glints.com/id/opportunities/jobs/sales...
# 23  https://glints.com/id/opportunities/jobs/sales...
# 17  https://glints.com/id/opportunities/jobs/senio...
# 14  https://glints.com/id/opportunities/jobs/site-...
# 19  https://glints.com/id/opportunities/jobs/teles...
# 1   https://glints.com/id/opportunities/jobs/ios-e...
